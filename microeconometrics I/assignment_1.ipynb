# %%
import pandas as pd
from statsmodels.formula.api import ols
import numpy as np

# %% [markdown]
# ## Explanatory analysis

# %%
df = pd.read_stata("assignment_1.dta", convert_dates=False)

# %%
df.head(7)
# Out:
#    county  year    crmrte    prbarr   prbconv   prbpris  avgsen     polpc  \
# 0       1    81  0.039885  0.289696  0.402062  0.472222    5.61  0.001787
# 1       1    82  0.038345  0.338111  0.433005  0.506993    5.59  0.001767
# 2       1    83  0.030305  0.330449  0.525703  0.479705    5.80  0.001836
# 3       1    84  0.034726  0.362525  0.604706  0.520104    6.89  0.001886
# 4       1    85  0.036573  0.325395  0.578723  0.497059    6.55  0.001924
# 5       1    86  0.034752  0.326062  0.512324  0.439863    6.90  0.001895
# 6       1    87  0.035604  0.298270  0.527596  0.436170    6.71  0.001828
#
#     density      taxpc  ...   lpctmin  clcrmrte  clprbarr  clprbcon  clprbpri  \
# 0  2.307159  25.697630  ...  3.006608       NaN       NaN       NaN       NaN
# 1  2.330254  24.874252  ...  3.006608 -0.039376  0.154542  0.074143  0.071048
# 2  2.341801  26.451443  ...  3.006608 -0.235316 -0.022922  0.193987 -0.055326
# 3  2.346420  26.842348  ...  3.006608  0.136180  0.092641  0.140006  0.080857
# 4  2.364896  28.140337  ...  3.006608  0.051825 -0.108054 -0.043918 -0.045320
# 5  2.385681  29.740980  ...  3.006608 -0.051062  0.002048 -0.121867 -0.122245
# 6  2.422633  30.993681  ...  3.006608  0.024198 -0.089089  0.029374 -0.008431
#
#    clavgsen   clpolpc   cltaxpc     clmix  trend
# 0       NaN       NaN       NaN       NaN    1.0
# 1 -0.003571 -0.011364 -0.032565  0.030857    2.0
# 2  0.036879  0.038413  0.061477 -0.244732    3.0
# 3  0.172213  0.026930  0.014670 -0.027331    4.0
# 4 -0.050606  0.020199  0.047223  0.172125    5.0
# 5  0.052056 -0.015258  0.055322  0.042765    6.0
# 6 -0.027923 -0.036189  0.041257 -0.193899    7.0
#
# [7 rows x 54 columns]

# %%
df[[
    "crmrte", 
    "prbconv", 
    "prbarr", 
    "avgsen", 
    "polpc",
    "density",
    'taxpc', 
    'west', 
    'central', 
    'urban'
]]
# Out:
#        crmrte   prbconv    prbarr  avgsen     polpc   density      taxpc  \
# 0    0.039885  0.402062  0.289696    5.61  0.001787  2.307159  25.697630
# 1    0.038345  0.433005  0.338111    5.59  0.001767  2.330254  24.874252
# 2    0.030305  0.525703  0.330449    5.80  0.001836  2.341801  26.451443
# 3    0.034726  0.604706  0.362525    6.89  0.001886  2.346420  26.842348
# 4    0.036573  0.578723  0.325395    6.55  0.001924  2.364896  28.140337
# ..        ...       ...       ...     ...       ...       ...        ...
# 625  0.015575  0.480392  0.226667    7.77  0.001073  0.869048  18.905853
# 626  0.013662  1.410260  0.204188   10.11  0.001109  0.872024  22.704754
# 627  0.013086  0.830769  0.180556    5.96  0.001054  0.875000  24.123611
# 628  0.012874  2.250000  0.112676    7.68  0.001088  0.880952  24.981979
# 629  0.014193  1.182930  0.207595   12.23  0.001186  0.889881  25.952581
#
#      west  central  urban
# 0       0        1      0
# 1       0        1      0
# 2       0        1      0
# 3       0        1      0
# 4       0        1      0
# ..    ...      ...    ...
# 625     1        0      0
# 626     1        0      0
# 627     1        0      0
# 628     1        0      0
# 629     1        0      0
#
# [630 rows x 10 columns]

# %%
df = df.assign(
    log_crmrte=np.log(df["crmrte"]),
    log_prbconv = np.log(df["prbconv"]),
    log_prbarr = np.log(df["prbarr"]),
    log_avgsen = np.log(df["avgsen"]),
    log_polpc = np.log(df["polpc"]),
    log_density = np.log(df["density"])
    )

log_variables = [column for column in df.columns if column.split("_")[0] == "log" and column != "log_crmrte"]
dependent_variable = ["log_crmrte"]

# %%
df_final = df.dropna()

# %%
len(list(df_final.county.unique()))
# Out:
# 90

# %% [markdown]
# ## Estimations

# %% [markdown]
# - Pooled OLS

# %%
pooled_ols = ols("log_crmrte ~" + " + ".join(log_variables+["west", "central", "urban"]), data=df_final).fit()
print(pooled_ols.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log_crmrte   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     217.3
# Date:                Fri, 10 Mar 2023   Prob (F-statistic):          4.93e-162
# Time:                        14:24:29   Log-Likelihood:                -77.694
# No. Observations:                 540   AIC:                             173.4
# Df Residuals:                     531   BIC:                             212.0
# Df Model:                           8
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -1.8795      0.189     -9.921      0.000      -2.252      -1.507
# log_prbconv    -0.4039      0.025    -16.369      0.000      -0.452      -0.355
# log_prbarr     -0.5324      0.034    -15.671      0.000      -0.599      -0.466
# log_avgsen     -0.1369      0.048     -2.876      0.004      -0.230      -0.043
# log_polpc       0.3354      0.025     13.372      0.000       0.286       0.385
# log_density     0.2542      0.026      9.790      0.000       0.203       0.305
# west           -0.5621      0.032    -17.609      0.000      -0.625      -0.499
# central        -0.2417      0.030     -7.968      0.000      -0.301      -0.182
# urban          -0.0197      0.058     -0.340      0.734      -0.133       0.094
# ==============================================================================
# Omnibus:                       58.759   Durbin-Watson:                   0.658
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              207.133
# Skew:                          -0.447   Prob(JB):                     1.05e-45
# Kurtosis:                       5.899   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - Random Effects

# %%
pooled_ols = ols(
    "log_crmrte ~" + " + ".join(log_variables+["west", "central", "urban"]), 
    data=df_final).\
    fit()
print(pooled_ols.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log_crmrte   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     217.3
# Date:                Thu, 09 Mar 2023   Prob (F-statistic):          4.93e-162
# Time:                        19:39:53   Log-Likelihood:                -77.694
# No. Observations:                 540   AIC:                             173.4
# Df Residuals:                     531   BIC:                             212.0
# Df Model:                           8
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -1.8795      0.189     -9.921      0.000      -2.252      -1.507
# log_prbconv    -0.4039      0.025    -16.369      0.000      -0.452      -0.355
# log_prbarr     -0.5324      0.034    -15.671      0.000      -0.599      -0.466
# log_avgsen     -0.1369      0.048     -2.876      0.004      -0.230      -0.043
# log_polpc       0.3354      0.025     13.372      0.000       0.286       0.385
# log_density     0.2542      0.026      9.790      0.000       0.203       0.305
# west           -0.5621      0.032    -17.609      0.000      -0.625      -0.499
# central        -0.2417      0.030     -7.968      0.000      -0.301      -0.182
# urban          -0.0197      0.058     -0.340      0.734      -0.133       0.094
# ==============================================================================
# Omnibus:                       58.759   Durbin-Watson:                   0.658
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              207.133
# Skew:                          -0.447   Prob(JB):                     1.05e-45
# Kurtosis:                       5.899   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - Fixed Effects
#
# (I have to make an F-test comparing the restricted model with the unrestricted one, where the unrestricted model is the model with all dummies added)

# %%
dummy_vars = pd.get_dummies(df_final["year"].astype(str), prefix="year")
dummy_vars
# Out:
#      year_82  year_83  year_84  year_85  year_86  year_87
# 1          1        0        0        0        0        0
# 2          0        1        0        0        0        0
# 3          0        0        1        0        0        0
# 4          0        0        0        1        0        0
# 5          0        0        0        0        1        0
# ..       ...      ...      ...      ...      ...      ...
# 625        0        1        0        0        0        0
# 626        0        0        1        0        0        0
# 627        0        0        0        1        0        0
# 628        0        0        0        0        1        0
# 629        0        0        0        0        0        1
#
# [540 rows x 6 columns]

# %%
df_fixed_effects = pd.concat([df_final, dummy_vars], axis=1)

year_dummy_columns = list(dummy_vars.columns)[1:] # year_82 is removed to avoid multicollinearity
geographical_columns = ["west", "central", "urban"]

fixed_effects_ols = ols(
    "log_crmrte ~" + " + ".join(log_variables+geographical_columns+year_dummy_columns), 
    data=df_fixed_effects).\
    fit(cov_type='cluster', cov_kwds={'groups': df_fixed_effects['county']})
    
print(fixed_effects_ols.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log_crmrte   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     66.60
# Date:                Fri, 10 Mar 2023   Prob (F-statistic):           4.88e-40
# Time:                        14:37:22   Log-Likelihood:                -71.700
# No. Observations:                 540   AIC:                             171.4
# Df Residuals:                     526   BIC:                             231.5
# Df Model:                          13
# Covariance Type:              cluster
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -1.7624      0.760     -2.319      0.020      -3.252      -0.273
# log_prbconv    -0.3969      0.062     -6.390      0.000      -0.519      -0.275
# log_prbarr     -0.5281      0.108     -4.902      0.000      -0.739      -0.317
# log_avgsen     -0.1481      0.081     -1.818      0.069      -0.308       0.012
# log_polpc       0.3373      0.109      3.098      0.002       0.124       0.551
# log_density     0.2584      0.060      4.272      0.000       0.140       0.377
# west           -0.5628      0.074     -7.623      0.000      -0.708      -0.418
# central        -0.2438      0.057     -4.245      0.000      -0.356      -0.131
# urban          -0.0204      0.076     -0.269      0.788      -0.169       0.128
# year_83        -0.0678      0.019     -3.491      0.000      -0.106      -0.030
# year_84        -0.1221      0.020     -6.186      0.000      -0.161      -0.083
# year_85        -0.1116      0.026     -4.324      0.000      -0.162      -0.061
# year_86        -0.0783      0.025     -3.094      0.002      -0.128      -0.029
# year_87        -0.0380      0.029     -1.295      0.195      -0.096       0.020
# ==============================================================================
# Omnibus:                       59.966   Durbin-Watson:                   0.644
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              226.975
# Skew:                          -0.434   Prob(JB):                     5.16e-50
# Kurtosis:                       6.055   Cond. No.                         115.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
