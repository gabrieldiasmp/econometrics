# %%
import pandas as pd
from statsmodels.formula.api import ols
import statsmodels.api as sm
import numpy as np

# %% [markdown]
# ## Explanatory analysis

# %%
df = pd.read_stata("assignment_1.dta", convert_dates=False)

# %%
df.head(7)
# Out:
#    county  year    crmrte    prbarr   prbconv   prbpris  avgsen     polpc  \
# 0       1    81  0.039885  0.289696  0.402062  0.472222    5.61  0.001787
# 1       1    82  0.038345  0.338111  0.433005  0.506993    5.59  0.001767
# 2       1    83  0.030305  0.330449  0.525703  0.479705    5.80  0.001836
# 3       1    84  0.034726  0.362525  0.604706  0.520104    6.89  0.001886
# 4       1    85  0.036573  0.325395  0.578723  0.497059    6.55  0.001924
# 5       1    86  0.034752  0.326062  0.512324  0.439863    6.90  0.001895
# 6       1    87  0.035604  0.298270  0.527596  0.436170    6.71  0.001828
#
#     density      taxpc  ...   lpctmin  clcrmrte  clprbarr  clprbcon  clprbpri  \
# 0  2.307159  25.697630  ...  3.006608       NaN       NaN       NaN       NaN
# 1  2.330254  24.874252  ...  3.006608 -0.039376  0.154542  0.074143  0.071048
# 2  2.341801  26.451443  ...  3.006608 -0.235316 -0.022922  0.193987 -0.055326
# 3  2.346420  26.842348  ...  3.006608  0.136180  0.092641  0.140006  0.080857
# 4  2.364896  28.140337  ...  3.006608  0.051825 -0.108054 -0.043918 -0.045320
# 5  2.385681  29.740980  ...  3.006608 -0.051062  0.002048 -0.121867 -0.122245
# 6  2.422633  30.993681  ...  3.006608  0.024198 -0.089089  0.029374 -0.008431
#
#    clavgsen   clpolpc   cltaxpc     clmix  trend
# 0       NaN       NaN       NaN       NaN    1.0
# 1 -0.003571 -0.011364 -0.032565  0.030857    2.0
# 2  0.036879  0.038413  0.061477 -0.244732    3.0
# 3  0.172213  0.026930  0.014670 -0.027331    4.0
# 4 -0.050606  0.020199  0.047223  0.172125    5.0
# 5  0.052056 -0.015258  0.055322  0.042765    6.0
# 6 -0.027923 -0.036189  0.041257 -0.193899    7.0
#
# [7 rows x 54 columns]

# %%
df[[
    "crmrte", 
    "prbconv", 
    "prbarr", 
    "avgsen", 
    "polpc",
    "density",
    'taxpc', 
    'west', 
    'central', 
    'urban'
]]
# Out:
#        crmrte   prbconv    prbarr  avgsen     polpc   density      taxpc  \
# 0    0.039885  0.402062  0.289696    5.61  0.001787  2.307159  25.697630
# 1    0.038345  0.433005  0.338111    5.59  0.001767  2.330254  24.874252
# 2    0.030305  0.525703  0.330449    5.80  0.001836  2.341801  26.451443
# 3    0.034726  0.604706  0.362525    6.89  0.001886  2.346420  26.842348
# 4    0.036573  0.578723  0.325395    6.55  0.001924  2.364896  28.140337
# ..        ...       ...       ...     ...       ...       ...        ...
# 625  0.015575  0.480392  0.226667    7.77  0.001073  0.869048  18.905853
# 626  0.013662  1.410260  0.204188   10.11  0.001109  0.872024  22.704754
# 627  0.013086  0.830769  0.180556    5.96  0.001054  0.875000  24.123611
# 628  0.012874  2.250000  0.112676    7.68  0.001088  0.880952  24.981979
# 629  0.014193  1.182930  0.207595   12.23  0.001186  0.889881  25.952581
#
#      west  central  urban
# 0       0        1      0
# 1       0        1      0
# 2       0        1      0
# 3       0        1      0
# 4       0        1      0
# ..    ...      ...    ...
# 625     1        0      0
# 626     1        0      0
# 627     1        0      0
# 628     1        0      0
# 629     1        0      0
#
# [630 rows x 10 columns]

# %%
df = df.assign(
    log_crmrte=np.log(df["crmrte"]),
    log_prbconv = np.log(df["prbconv"]),
    log_prbarr = np.log(df["prbarr"]),
    log_avgsen = np.log(df["avgsen"]),
    log_polpc = np.log(df["polpc"]),
    log_density = np.log(df["density"])
)

log_variables = [column for column in df.columns if column.split("_")[0] == "log" and column != "log_crmrte"]
dependent_variable = ["log_crmrte"]

# %%
df_final = df.dropna()

# Generate dummy variables for years
dummy_vars = pd.get_dummies(df_final["year"].astype(str), prefix="year")
df_final = pd.concat([df_final, dummy_vars], axis=1)

dummy_vars
# Out:
#      year_82  year_83  year_84  year_85  year_86  year_87
# 1          1        0        0        0        0        0
# 2          0        1        0        0        0        0
# 3          0        0        1        0        0        0
# 4          0        0        0        1        0        0
# 5          0        0        0        0        1        0
# ..       ...      ...      ...      ...      ...      ...
# 625        0        1        0        0        0        0
# 626        0        0        1        0        0        0
# 627        0        0        0        1        0        0
# 628        0        0        0        0        1        0
# 629        0        0        0        0        0        1
#
# [540 rows x 6 columns]

# %% [markdown]
# - Describing columns

# %%
year_dummy_columns = list(dummy_vars.columns)[1:] # year_82 is removed to avoid multicollinearity
geographical_columns = ["west", "central", "urban"]

# %% [markdown]
# ## Estimations

# %% [markdown]
# - Pooled OLS

# %%
pooled_ols = ols("log_crmrte ~" + " + ".join(log_variables+geographical_columns+year_dummy_columns), data=df_final).fit()
print(pooled_ols.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log_crmrte   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     136.3
# Date:                Mon, 13 Mar 2023   Prob (F-statistic):          6.88e-159
# Time:                        20:11:04   Log-Likelihood:                -71.700
# No. Observations:                 540   AIC:                             171.4
# Df Residuals:                     526   BIC:                             231.5
# Df Model:                          13
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -1.7624      0.192     -9.202      0.000      -2.139      -1.386
# log_prbconv    -0.3969      0.025    -16.096      0.000      -0.445      -0.348
# log_prbarr     -0.5281      0.034    -15.604      0.000      -0.595      -0.462
# log_avgsen     -0.1481      0.048     -3.068      0.002      -0.243      -0.053
# log_polpc       0.3373      0.025     13.506      0.000       0.288       0.386
# log_density     0.2584      0.026     10.001      0.000       0.208       0.309
# west           -0.5628      0.032    -17.742      0.000      -0.625      -0.500
# central        -0.2438      0.030     -8.088      0.000      -0.303      -0.185
# urban          -0.0204      0.058     -0.354      0.724      -0.134       0.093
# year_83        -0.0678      0.042     -1.622      0.106      -0.150       0.014
# year_84        -0.1221      0.042     -2.919      0.004      -0.204      -0.040
# year_85        -0.1116      0.042     -2.659      0.008      -0.194      -0.029
# year_86        -0.0783      0.042     -1.869      0.062      -0.161       0.004
# year_87        -0.0380      0.042     -0.897      0.370      -0.121       0.045
# ==============================================================================
# Omnibus:                       59.966   Durbin-Watson:                   0.644
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              226.975
# Skew:                          -0.434   Prob(JB):                     5.16e-50
# Kurtosis:                       6.055   Cond. No.                         115.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - Random Effects (with linearmodels)

# %%
from linearmodels.panel import RandomEffects

random_effects_df = df_final.set_index(['county', 'trend'])

exog = sm.add_constant(random_effects_df[log_variables+geographical_columns+year_dummy_columns])

re_model = RandomEffects(random_effects_df.log_crmrte, exog).\
    fit()

print(re_model.summary)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:             log_crmrte   R-squared:                        0.5375
# Estimator:              RandomEffects   R-squared (Between):              0.7721
# No. Observations:                 540   R-squared (Within):               0.4043
# Date:                Mon, Mar 13 2023   R-squared (Overall):              0.7428
# Time:                        20:11:10   Log-likelihood                    300.00
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      47.015
# Entities:                          90   P-value                           0.0000
# Avg Obs:                       6.0000   Distribution:                  F(13,526)
# Min Obs:                       6.0000
# Max Obs:                       6.0000   F-statistic (robust):             47.015
#                                         P-value                           0.0000
# Time periods:                       6   Distribution:                  F(13,526)
# Avg Obs:                       90.000
# Min Obs:                       90.000
# Max Obs:                       90.000
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# const          -1.3067     0.1781    -7.3387     0.0000     -1.6564     -0.9569
# log_prbconv    -0.2715     0.0214    -12.711     0.0000     -0.3134     -0.2295
# log_prbarr     -0.3309     0.0330    -10.035     0.0000     -0.3957     -0.2661
# log_avgsen     -0.0693     0.0302    -2.2993     0.0219     -0.1286     -0.0101
# log_polpc       0.3757     0.0265     14.185     0.0000      0.3237      0.4277
# log_density     0.3633     0.0514     7.0653     0.0000      0.2623      0.4643
# west           -0.5717     0.0716    -7.9834     0.0000     -0.7124     -0.4310
# central        -0.2847     0.0675    -4.2198     0.0000     -0.4172     -0.1521
# urban          -0.0822     0.1271    -0.6470     0.5179     -0.3320      0.1675
# year_83        -0.0829     0.0211    -3.9294     0.0001     -0.1243     -0.0414
# year_84        -0.1413     0.0212    -6.6788     0.0000     -0.1829     -0.0997
# year_85        -0.1354     0.0213    -6.3451     0.0000     -0.1773     -0.0935
# year_86        -0.0921     0.0213    -4.3333     0.0000     -0.1339     -0.0504
# year_87        -0.0484     0.0218    -2.2191     0.0269     -0.0913     -0.0056
# ===============================================================================
# /Users/gabrieldiasmp/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# - Fixed Effects (with linearmodels)

# %%
# (we should test time fixed effects by calculating the joint significance of the dummy variables)

from linearmodels import PanelOLS

fixed_effects_df = df_final.set_index(['county', 'trend'])

exog = sm.add_constant(fixed_effects_df[log_variables+geographical_columns+year_dummy_columns])

fe_model = PanelOLS(fixed_effects_df.log_crmrte, exog).fit(cov_type="clustered", cluster_entity=True) #cov_type="clustered", cluster_entity=True

print(fe_model.summary)

## With statsmodels, just in case
# fixed_effects_ols = ols(
#     "log_crmrte ~" + " + ".join(log_variables+geographical_columns+year_dummy_columns), 
#     data=df_final).\
#     fit(cov_type='cluster', cov_kwds={'groups': df_final['county']})
    
# print(fixed_effects_ols.summary())
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:             log_crmrte   R-squared:                        0.7711
# Estimator:                   PanelOLS   R-squared (Between):              0.8141
# No. Observations:                 540   R-squared (Within):               0.2751
# Date:                Mon, Mar 13 2023   R-squared (Overall):              0.7711
# Time:                        20:11:27   Log-likelihood                   -71.700
# Cov. Estimator:             Clustered
#                                         F-statistic:                      136.32
# Entities:                          90   P-value                           0.0000
# Avg Obs:                       6.0000   Distribution:                  F(13,526)
# Min Obs:                       6.0000
# Max Obs:                       6.0000   F-statistic (robust):             67.221
#                                         P-value                           0.0000
# Time periods:                       6   Distribution:                  F(13,526)
# Avg Obs:                       90.000
# Min Obs:                       90.000
# Max Obs:                       90.000
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# const          -1.7624     0.7564    -2.3300     0.0202     -3.2483     -0.2765
# log_prbconv    -0.3969     0.0618    -6.4201     0.0000     -0.5184     -0.2755
# log_prbarr     -0.5281     0.1072    -4.9250     0.0000     -0.7387     -0.3174
# log_avgsen     -0.1481     0.0811    -1.8263     0.0684     -0.3073      0.0112
# log_polpc       0.3373     0.1084     3.1127     0.0020      0.1244      0.5502
# log_density     0.2584     0.0602     4.2916     0.0000      0.1401      0.3767
# west           -0.5628     0.0735    -7.6582     0.0000     -0.7072     -0.4184
# central        -0.2438     0.0572    -4.2650     0.0000     -0.3561     -0.1315
# urban          -0.0204     0.0754    -0.2704     0.7870     -0.1686      0.1278
# year_83        -0.0678     0.0193    -3.5073     0.0005     -0.1058     -0.0298
# year_84        -0.1221     0.0196    -6.2148     0.0000     -0.1607     -0.0835
# year_85        -0.1116     0.0257    -4.3442     0.0000     -0.1620     -0.0611
# year_86        -0.0783     0.0252    -3.1087     0.0020     -0.1278     -0.0288
# year_87        -0.0380     0.0292    -1.3007     0.1939     -0.0954      0.0194
# ===============================================================================

# %% [markdown]
# - Hausman test (to be tested)

# %%
from scipy.stats import chi2

# get the covariance matrices for the two models
cov_fixed = fe_model.cov
cov_random = re_model.cov

# calculate the difference in the estimated coefficients
b_diff = fe_model.params - re_model.params

# calculate the covariance matrix of the difference
cov_b_diff = cov_fixed - cov_random

# calculate the Hausman test statistic
hausman_stat = np.dot(b_diff.T, np.linalg.inv(cov_b_diff)).dot(b_diff)

# calculate the p-value of the test
p_value = 1 - chi2.cdf(hausman_stat, df=cov_b_diff.shape[0])

# print the results
print('Hausman test statistic: {:.4f}'.format(hausman_stat))
print('p-value: {:.4f}'.format(p_value))
# Out:
# Hausman test statistic: 7.6458
# p-value: 0.9069
