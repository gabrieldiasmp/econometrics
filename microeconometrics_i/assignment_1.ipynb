# %% [markdown]
# ## Setup

# %%
import pandas as pd
from statsmodels.formula.api import ols
import statsmodels.api as sm
#from linearmodels import PanelOLS
from linearmodels.panel import RandomEffects, PooledOLS, PanelOLS, FirstDifferenceOLS
import numpy as np

# %% [markdown]
# ## Explanatory analysis

# %%
df = pd.read_stata("assignment_1.dta", convert_dates=False)

# %%
df.head(7)
# Out:
#    county  year    crmrte    prbarr   prbconv   prbpris  avgsen     polpc  \
# 0       1    81  0.039885  0.289696  0.402062  0.472222    5.61  0.001787
# 1       1    82  0.038345  0.338111  0.433005  0.506993    5.59  0.001767
# 2       1    83  0.030305  0.330449  0.525703  0.479705    5.80  0.001836
# 3       1    84  0.034726  0.362525  0.604706  0.520104    6.89  0.001886
# 4       1    85  0.036573  0.325395  0.578723  0.497059    6.55  0.001924
# 5       1    86  0.034752  0.326062  0.512324  0.439863    6.90  0.001895
# 6       1    87  0.035604  0.298270  0.527596  0.436170    6.71  0.001828
#
#     density      taxpc  ...   lpctmin  clcrmrte  clprbarr  clprbcon  clprbpri  \
# 0  2.307159  25.697630  ...  3.006608       NaN       NaN       NaN       NaN
# 1  2.330254  24.874252  ...  3.006608 -0.039376  0.154542  0.074143  0.071048
# 2  2.341801  26.451443  ...  3.006608 -0.235316 -0.022922  0.193987 -0.055326
# 3  2.346420  26.842348  ...  3.006608  0.136180  0.092641  0.140006  0.080857
# 4  2.364896  28.140337  ...  3.006608  0.051825 -0.108054 -0.043918 -0.045320
# 5  2.385681  29.740980  ...  3.006608 -0.051062  0.002048 -0.121867 -0.122245
# 6  2.422633  30.993681  ...  3.006608  0.024198 -0.089089  0.029374 -0.008431
#
#    clavgsen   clpolpc   cltaxpc     clmix  trend
# 0       NaN       NaN       NaN       NaN    1.0
# 1 -0.003571 -0.011364 -0.032565  0.030857    2.0
# 2  0.036879  0.038413  0.061477 -0.244732    3.0
# 3  0.172213  0.026930  0.014670 -0.027331    4.0
# 4 -0.050606  0.020199  0.047223  0.172125    5.0
# 5  0.052056 -0.015258  0.055322  0.042765    6.0
# 6 -0.027923 -0.036189  0.041257 -0.193899    7.0
#
# [7 rows x 54 columns]

# %%
df[[
    "crmrte", 
    "prbconv", 
    "prbarr", 
    "avgsen", 
    "polpc",
    "density",
    'taxpc', 
    'west', 
    'central', 
    'urban'
]]
# Out:
#        crmrte   prbconv    prbarr  avgsen     polpc   density      taxpc  \
# 0    0.039885  0.402062  0.289696    5.61  0.001787  2.307159  25.697630
# 1    0.038345  0.433005  0.338111    5.59  0.001767  2.330254  24.874252
# 2    0.030305  0.525703  0.330449    5.80  0.001836  2.341801  26.451443
# 3    0.034726  0.604706  0.362525    6.89  0.001886  2.346420  26.842348
# 4    0.036573  0.578723  0.325395    6.55  0.001924  2.364896  28.140337
# ..        ...       ...       ...     ...       ...       ...        ...
# 625  0.015575  0.480392  0.226667    7.77  0.001073  0.869048  18.905853
# 626  0.013662  1.410260  0.204188   10.11  0.001109  0.872024  22.704754
# 627  0.013086  0.830769  0.180556    5.96  0.001054  0.875000  24.123611
# 628  0.012874  2.250000  0.112676    7.68  0.001088  0.880952  24.981979
# 629  0.014193  1.182930  0.207595   12.23  0.001186  0.889881  25.952581
#
#      west  central  urban
# 0       0        1      0
# 1       0        1      0
# 2       0        1      0
# 3       0        1      0
# 4       0        1      0
# ..    ...      ...    ...
# 625     1        0      0
# 626     1        0      0
# 627     1        0      0
# 628     1        0      0
# 629     1        0      0
#
# [630 rows x 10 columns]

# %%
df = df.assign(
    log_crmrte=np.log(df["crmrte"]),
    log_prbconv = np.log(df["prbconv"]),
    log_prbarr = np.log(df["prbarr"]),
    log_avgsen = np.log(df["avgsen"]),
    log_polpc = np.log(df["polpc"]),
    log_density = np.log(df["density"])
)

independent_variables = [column for column in df.columns if column.split("_")[0] == "log" and column != "log_crmrte"] + ['taxpc']
dependent_variable = ["log_crmrte"]
geographical_columns = ["west", "central", "urban"]
index_columns = ['county', 'trend', 'year']

df_final = df[independent_variables+dependent_variable+geographical_columns+index_columns]

# %%
df_final = df.dropna()

# Generate dummy variables for years
dummy_vars = pd.get_dummies(df_final["year"].astype(str), prefix="year")
df_final = pd.concat([df_final, dummy_vars], axis=1)
year_dummy_columns = list(dummy_vars.columns)[1:] # year_82 is removed to avoid multicollinearity

dummy_vars
# Out:
#      year_82  year_83  year_84  year_85  year_86  year_87
# 1          1        0        0        0        0        0
# 2          0        1        0        0        0        0
# 3          0        0        1        0        0        0
# 4          0        0        0        1        0        0
# 5          0        0        0        0        1        0
# ..       ...      ...      ...      ...      ...      ...
# 625        0        1        0        0        0        0
# 626        0        0        1        0        0        0
# 627        0        0        0        1        0        0
# 628        0        0        0        0        1        0
# 629        0        0        0        0        0        1
#
# [540 rows x 6 columns]

# %% [markdown]
# ## Estimations

# %% [markdown]
# - Pooled OLS

# %%
# pooled_ols = ols("log_crmrte ~" + " + ".join(log_variables+geographical_columns+["C(year)"]), data=df_final).fit()
# print(pooled_ols.summary())

pooled_ols_df = df_final.set_index(['county', 'trend'])

pooled_ols = PooledOLS.\
    from_formula("log_crmrte ~ 1 +" + " + ".join(independent_variables+geographical_columns+["C(year)"]), data=pooled_ols_df).\
    fit(cov_type="robust")

print(pooled_ols.summary)
# Out:
#                           PooledOLS Estimation Summary
# ================================================================================
# Dep. Variable:             log_crmrte   R-squared:                        0.7784
# Estimator:                  PooledOLS   R-squared (Between):              0.8283
# No. Observations:                 630   R-squared (Within):               0.2560
# Date:                Tue, Mar 14 2023   R-squared (Overall):              0.7784
# Time:                        19:30:17   Log-likelihood                   -67.723
# Cov. Estimator:                Robust
#                                         F-statistic:                      143.78
# Entities:                          90   P-value                           0.0000
# Avg Obs:                       7.0000   Distribution:                  F(15,614)
# Min Obs:                       7.0000
# Max Obs:                       7.0000   F-statistic (robust):             243.02
#                                         P-value                           0.0000
# Time periods:                       7   Distribution:                  F(15,614)
# Avg Obs:                       90.000
# Min Obs:                       90.000
# Max Obs:                       90.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# Intercept        -1.7880     0.3789    -4.7189     0.0000     -2.5322     -1.0439
# C(year)[T.82]    -0.0150     0.0369    -0.4080     0.6834     -0.0875      0.0574
# C(year)[T.83]    -0.0825     0.0391    -2.1082     0.0354     -0.1593     -0.0056
# C(year)[T.84]    -0.1348     0.0397    -3.3980     0.0007     -0.2128     -0.0569
# C(year)[T.85]    -0.1216     0.0427    -2.8461     0.0046     -0.2056     -0.0377
# C(year)[T.86]    -0.0874     0.0431    -2.0282     0.0430     -0.1721     -0.0028
# C(year)[T.87]    -0.0464     0.0418    -1.1097     0.2676     -0.1285      0.0357
# central          -0.2379     0.0254    -9.3555     0.0000     -0.2879     -0.1880
# log_avgsen       -0.1361     0.0522    -2.6085     0.0093     -0.2385     -0.0336
# log_density       0.2620     0.0293     8.9271     0.0000      0.2043      0.3196
# log_polpc         0.3307     0.0514     6.4347     0.0000      0.2298      0.4316
# log_prbarr       -0.5188     0.0491    -10.565     0.0000     -0.6152     -0.4224
# log_prbconv      -0.3951     0.0325    -12.141     0.0000     -0.4590     -0.3312
# taxpc            -0.0006     0.0016    -0.3671     0.7137     -0.0037      0.0026
# urban            -0.0227     0.0414    -0.5477     0.5841     -0.1039      0.0586
# west             -0.5701     0.0335    -17.024     0.0000     -0.6359     -0.5043
# =================================================================================

# %% [markdown]
# - Random Effects (with linearmodels)

# %%
random_effects_df = df_final.set_index(['county', 'trend'])

re_model = RandomEffects.from_formula(
    "log_crmrte ~ 1 +" + " + ".join(independent_variables+geographical_columns+["C(year)"]),
    random_effects_df
).fit(cov_type="robust") #cov_type="robust"

print(re_model.summary)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:             log_crmrte   R-squared:                        0.5298
# Estimator:              RandomEffects   R-squared (Between):              0.7810
# No. Observations:                 630   R-squared (Within):               0.4005
# Date:                Tue, Mar 14 2023   R-squared (Overall):              0.7478
# Time:                        19:30:25   Log-likelihood                    333.01
# Cov. Estimator:                Robust
#                                         F-statistic:                      46.130
# Entities:                          90   P-value                           0.0000
# Avg Obs:                       7.0000   Distribution:                  F(15,614)
# Min Obs:                       7.0000
# Max Obs:                       7.0000   F-statistic (robust):             38.412
#                                         P-value                           0.0000
# Time periods:                       7   Distribution:                  F(15,614)
# Avg Obs:                       90.000
# Min Obs:                       90.000
# Max Obs:                       90.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# Intercept        -1.3577     0.3386    -4.0101     0.0001     -2.0226     -0.6928
# C(year)[T.82]     0.0036     0.0215     0.1682     0.8665     -0.0386      0.0458
# C(year)[T.83]    -0.0822     0.0226    -3.6381     0.0003     -0.1266     -0.0378
# C(year)[T.84]    -0.1409     0.0223    -6.3302     0.0000     -0.1846     -0.0972
# C(year)[T.85]    -0.1361     0.0280    -4.8660     0.0000     -0.1910     -0.0811
# C(year)[T.86]    -0.0960     0.0265    -3.6267     0.0003     -0.1480     -0.0440
# C(year)[T.87]    -0.0587     0.0264    -2.2183     0.0269     -0.1106     -0.0067
# central          -0.2768     0.0626    -4.4242     0.0000     -0.3996     -0.1539
# log_avgsen       -0.0233     0.0339    -0.6863     0.4928     -0.0899      0.0433
# log_density       0.3602     0.0612     5.8882     0.0000      0.2401      0.4804
# log_polpc         0.3868     0.0507     7.6234     0.0000      0.2872      0.4865
# log_prbarr       -0.3410     0.0533    -6.3956     0.0000     -0.4457     -0.2363
# log_prbconv      -0.2693     0.0361    -7.4550     0.0000     -0.3403     -0.1984
# taxpc             0.0005     0.0011     0.4377     0.6618     -0.0017      0.0027
# urban            -0.1006     0.0963    -1.0447     0.2966     -0.2897      0.0885
# west             -0.5760     0.0789    -7.3036     0.0000     -0.7309     -0.4211
# =================================================================================

# %% [markdown]
# - Fixed Effects (with linearmodels)

# %%
# PanelOLS with_formula()
# (we should test time fixed effects by calculating the joint significance of the dummy variables)
# we can't add time-invariant variables, like the geographical ones!

fixed_effects_df = df_final.set_index(['county', 'trend'])

fe_model = PanelOLS.from_formula(
    "log_crmrte ~ 1 + " + " + ".join(independent_variables+["C(year)", "EntityEffects"]), #year_dummy_columns #"C(year)"
    data=fixed_effects_df
).fit(
    cov_type="clustered", cluster_entity=True
)

print(fe_model.summary)

## Example using different method
# exog = sm.add_constant(fixed_effects_df[log_variables+geographical_columns+year_dummy_columns])
# fe_model = PanelOLS(fixed_effects_df.log_crmrte, exog).fit(cov_type="clustered", cluster_entity=True) #cov_type="clustered", cluster_entity=True
# print(fe_model.summary)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:             log_crmrte   R-squared:                        0.4039
# Estimator:                   PanelOLS   R-squared (Between):              0.5742
# No. Observations:                 630   R-squared (Within):               0.4039
# Date:                Tue, Mar 14 2023   R-squared (Overall):              0.5594
# Time:                        19:30:35   Log-likelihood                    389.11
# Cov. Estimator:             Clustered
#                                         F-statistic:                      29.808
# Entities:                          90   P-value                           0.0000
# Avg Obs:                       7.0000   Distribution:                  F(12,528)
# Min Obs:                       7.0000
# Max Obs:                       7.0000   F-statistic (robust):             11.035
#                                         P-value                           0.0000
# Time periods:                       7   Distribution:                  F(12,528)
# Avg Obs:                       90.000
# Min Obs:                       90.000
# Max Obs:                       90.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# Intercept        -1.4800     0.5202    -2.8451     0.0046     -2.5020     -0.4581
# C(year)[T.82]     0.0042     0.0172     0.2422     0.8087     -0.0295      0.0379
# C(year)[T.83]    -0.0852     0.0210    -4.0563     0.0001     -0.1265     -0.0439
# C(year)[T.84]    -0.1460     0.0258    -5.6512     0.0000     -0.1968     -0.0953
# C(year)[T.85]    -0.1429     0.0333    -4.2959     0.0000     -0.2083     -0.0776
# C(year)[T.86]    -0.1014     0.0320    -3.1714     0.0016     -0.1643     -0.0386
# C(year)[T.87]    -0.0643     0.0374    -1.7176     0.0865     -0.1378      0.0092
# log_avgsen       -0.0127     0.0345    -0.3671     0.7137     -0.0805      0.0551
# log_density       0.4527     0.4050     1.1177     0.2642     -0.3430      1.2484
# log_polpc         0.3994     0.0853     4.6827     0.0000      0.2318      0.5669
# log_prbarr       -0.3033     0.0569    -5.3289     0.0000     -0.4151     -0.1915
# log_prbconv      -0.2487     0.0502    -4.9495     0.0000     -0.3474     -0.1500
# taxpc             0.0005     0.0012     0.4275     0.6692     -0.0018      0.0028
# =================================================================================
#
# F-test for Poolability: 34.961
# P-value: 0.0000
# Distribution: F(89,528)
#
# Included effects: Entity

# %% [markdown]
# - Hausman test
#
# Since we don't reject the null hypothesis that the coefficients from both methods are statistically equal, we should use Random Effects instead of Random Effects

# %%
# Hausman test of FE vs. RE
# look: http://www.upfie.net/downloads14.html
# It has an Wooldridge exercise solved 

from scipy.stats import chi2

# get the covariance matrices for the two models
b_fe_cov = fe_model.cov
b_re_cov = re_model.cov

# (I) find overlapping coefficients:
common_coef = set(fe_model.params.index).intersection(re_model.params.index)

# (II) calculate differences between FE and RE:
b_diff = np.array(fe_model.params[common_coef] - re_model.params[common_coef])
df = len(b_diff)
b_diff.reshape((df, 1))
b_cov_diff = np.array(b_fe_cov.loc[common_coef, common_coef] -
                      b_re_cov.loc[common_coef, common_coef])
b_cov_diff.reshape((df, df))

# (III) calculate test statistic:
stat = abs(np.transpose(b_diff) @ np.linalg.inv(b_cov_diff) @ b_diff)
pval = 1 - chi2.cdf(stat, df)


print(f'stat: {stat}')
print(f'pval: {pval}')
# Out:
# stat: 23.556729313272996
# pval: 0.03546089091857885

# %% [markdown]
# - Testing models for serial correlation (Wooldridge, 2022)

# %%
independent_variables
# Out:
# ['log_prbconv',
#  'log_prbarr',
#  'log_avgsen',
#  'log_polpc',
#  'log_density',
#  'taxpc']

# %%
first_difference_df = df_final.set_index(['county', 'trend'])
exog = first_difference_df[independent_variables]
first_difference_ols = FirstDifferenceOLS(first_difference_df.log_crmrte, exog).fit(cov_type="clustered", cluster_entity=True)

print(first_difference_ols.summary)
# Out:
#                      FirstDifferenceOLS Estimation Summary
# ================================================================================
# Dep. Variable:             log_crmrte   R-squared:                        0.3281
# Estimator:         FirstDifferenceOLS   R-squared (Between):              0.7715
# No. Observations:                 540   R-squared (Within):               0.3041
# Date:                Tue, Mar 14 2023   R-squared (Overall):              0.7705
# Time:                        21:58:01   Log-likelihood                    202.83
# Cov. Estimator:             Clustered
#                                         F-statistic:                      43.452
# Entities:                          90   P-value                           0.0000
# Avg Obs:                       7.0000   Distribution:                   F(6,534)
# Min Obs:                       7.0000
# Max Obs:                       7.0000   F-statistic (robust):             8.4744
#                                         P-value                           0.0000
# Time periods:                       7   Distribution:                   F(6,534)
# Avg Obs:                       90.000
# Min Obs:                       90.000
# Max Obs:                       90.000
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# log_prbconv    -0.2205     0.0364    -6.0531     0.0000     -0.2920     -0.1489
# log_prbarr     -0.2920     0.0541    -5.3992     0.0000     -0.3983     -0.1858
# log_avgsen     -0.0295     0.0275    -1.0715     0.2844     -0.0835      0.0245
# log_polpc       0.3731     0.0953     3.9157     0.0001      0.1859      0.5602
# log_density    -0.1638     0.3546    -0.4620     0.6443     -0.8604      0.5327
# taxpc           0.0004     0.0008     0.4659     0.6415     -0.0011      0.0019
# ===============================================================================

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox

residuals = first_difference_ols.resids

test_results = acorr_ljungbox(residuals, lags=[1])

test_statistic, p_value = test_results

if p_value < 0.05:
    print(f"There is evidence of within-group serial correlation in the residuals. P-value: {p_value}")
else:
    print(f"There is no evidence of within-group serial correlation in the residuals. P-value: {p_value}")
# Out:
# There is evidence of within-group serial correlation in the residuals. P-value: [0.00391233]
# /Users/gabrieldiasmp/opt/anaconda3/lib/python3.9/site-packages/statsmodels/stats/diagnostic.py:559: FutureWarning: The value returned will change to a single DataFrame after 0.12 is released.  Set return_df to True to use to return a DataFrame now.  Set return_df to False to silence this warning.
#   warnings.warn(msg, FutureWarning)

# %%
# As we can see below, our independent variables are significant after controlling fixed effects

restrictions = " = ".join(independent_variables) + " = 0"
fe_model.wald_test(formula=restrictions)
# Out:
# Linear Equality Hypothesis Test
# H0: Linear equality constraint is valid
# Statistic: 48.4867
# P-value: 0.0000
# Distributed: chi2(6)
# WaldTestStatistic, id: 0x7f8bd8d13d60

# %% [markdown]
# - Comparing the three models

# %%
from linearmodels.panel import compare

print(compare({"FE": fe_model, "RE": re_model, "Pooled": pooled_ols}))
# Out:
#                             Model Comparison
# =======================================================================
#                                     FE                RE         Pooled
# -----------------------------------------------------------------------
# Dep. Variable               log_crmrte        log_crmrte     log_crmrte
# Estimator                     PanelOLS     RandomEffects      PooledOLS
# No. Observations                   540               540            540
# Cov. Est.                    Clustered            Robust         Robust
# R-squared                       0.4104            0.5371         0.7714
# R-Squared (Within)              0.4104            0.4047         0.2711
# R-Squared (Between)             0.1974            0.7719         0.8147
# R-Squared (Overall)             0.2144            0.7427         0.7714
# F-statistic                     27.779            43.518         126.52
# P-value (F-stat)                0.0000            0.0000         0.0000
# =====================     ============   ===============   ============
# Intercept                      -1.4325           -1.3251        -1.7129
#                              (-2.7876)         (-3.7468)      (-4.1125)
# C(year)[T.83]                  -0.0896           -0.0832        -0.0672
#                              (-5.6302)         (-4.1848)      (-1.7185)
# C(year)[T.84]                  -0.1555           -0.1430        -0.1187
#                              (-7.9679)         (-7.1633)      (-2.9344)
# C(year)[T.85]                  -0.1564           -0.1390        -0.1045
#                              (-5.8203)         (-6.0434)      (-2.4817)
# C(year)[T.86]                  -0.1147           -0.0968        -0.0691
#                              (-4.3747)         (-4.3263)      (-1.6182)
# C(year)[T.87]                  -0.0745           -0.0546        -0.0263
#                              (-2.3083)         (-2.2823)      (-0.6131)
# log_avgsen                     -0.0622           -0.0690        -0.1477
#                              (-1.5556)         (-1.7493)      (-2.5532)
# log_density                     0.7972            0.3642         0.2540
#                               (2.1751)          (5.5277)       (7.6792)
# log_polpc                       0.3837            0.3751         0.3419
#                               (4.5066)          (7.0618)       (6.0585)
# log_prbarr                     -0.2864           -0.3315        -0.5309
#                              (-4.8223)         (-5.7321)      (-9.5237)
# log_prbconv                    -0.2476           -0.2715        -0.3988
#                              (-4.9226)         (-7.2004)      (-10.665)
# taxpc                           0.0002            0.0005        -0.0010
#                               (0.1932)          (0.4392)      (-0.5714)
# central                                          -0.2833        -0.2455
#                                                (-4.2788)      (-8.8668)
# urban                                            -0.0893        -0.0057
#                                                (-0.8730)      (-0.1231)
# west                                             -0.5689        -0.5685
#                                                (-6.8845)      (-15.524)
# ======================= ============== ================= ==============
# Effects                         Entity
# -----------------------------------------------------------------------
#
# T-stats reported in parentheses
